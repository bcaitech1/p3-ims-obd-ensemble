# %% [markdown]
# ## import

# %%
# !apt update
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Fetched 252 kB in 2s (119 kB/s)0m
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# All packages are up to date.

# %%
# !apt upgrade -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Calculating upgrade... Done
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.

# %%
# !apt install gcc python3-dev python3-pip libxml2-dev libxslt1-dev zlib1g-dev g++ -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-0ubuntu2).
# zlib1g-dev set to manually installed.
# gcc is already the newest version (4:7.4.0-1ubuntu2.3).
# The following additional packages will be installed:
#   build-essential dh-python dirmngr dpkg-dev fakeroot g++-7
#   gir1.2-harfbuzz-0.0 gnupg gnupg-l10n gnupg-utils gpg gpg-agent
#   gpg-wks-client gpg-wks-server gpgconf gpgsm icu-devtools
#   libalgorithm-diff-perl libalgorithm-diff-xs-perl libalgorithm-merge-perl
#   libassuan0 libdpkg-perl libelf1 libexpat1-dev libfakeroot
#   libfile-fcntllock-perl libfreetype6 libglib2.0-bin libglib2.0-dev
#   libglib2.0-dev-bin libgraphite2-3 libgraphite2-dev libharfbuzz-dev
#   libharfbuzz-gobject0 libharfbuzz-icu0 libharfbuzz0b libicu-dev
#   libicu-le-hb-dev libicu-le-hb0 libiculx60 libksba8 liblocale-gettext-perl
#   libnpth0 libpcre16-3 libpcre3-dev libpcre32-3 libpcrecpp0v5 libpython3-dev
#   libpython3.6-dev libstdc++-7-dev libxslt1.1 make pinentry-curses pkg-config
#   python-pip-whl python3-asn1crypto python3-cffi-backend python3-crypto
#   python3-cryptography python3-distutils python3-keyring python3-keyrings.alt
#   python3-lib2to3 python3-secretstorage python3-setuptools python3-wheel
#   python3-xdg python3.6-dev
# Suggested packages:
#   dbus-user-session pinentry-gnome3 tor debian-keyring g++-multilib
#   g++-7-multilib gcc-7-doc libstdc++6-7-dbg parcimonie xloadimage scdaemon bzr
#   libglib2.0-doc libgraphite2-utils icu-doc libstdc++-7-doc make-doc
#   pinentry-doc python-crypto-doc python-cryptography-doc
#   python3-cryptography-vectors gnome-keyring libkf5wallet-bin
#   gir1.2-gnomekeyring-1.0 python-secretstorage-doc python-setuptools-doc
# The following NEW packages will be installed:
#   build-essential dh-python dirmngr dpkg-dev fakeroot g++ g++-7
#   gir1.2-harfbuzz-0.0 gnupg gnupg-l10n gnupg-utils gpg gpg-agent
#   gpg-wks-client gpg-wks-server gpgconf gpgsm icu-devtools
#   libalgorithm-diff-perl libalgorithm-diff-xs-perl libalgorithm-merge-perl
#   libassuan0 libdpkg-perl libelf1 libexpat1-dev libfakeroot
#   libfile-fcntllock-perl libfreetype6 libglib2.0-bin libglib2.0-dev
#   libglib2.0-dev-bin libgraphite2-3 libgraphite2-dev libharfbuzz-dev
#   libharfbuzz-gobject0 libharfbuzz-icu0 libharfbuzz0b libicu-dev
#   libicu-le-hb-dev libicu-le-hb0 libiculx60 libksba8 liblocale-gettext-perl
#   libnpth0 libpcre16-3 libpcre3-dev libpcre32-3 libpcrecpp0v5 libpython3-dev
#   libpython3.6-dev libstdc++-7-dev libxml2-dev libxslt1-dev libxslt1.1 make
#   pinentry-curses pkg-config python-pip-whl python3-asn1crypto
#   python3-cffi-backend python3-crypto python3-cryptography python3-dev
#   python3-distutils python3-keyring python3-keyrings.alt python3-lib2to3
#   python3-pip python3-secretstorage python3-setuptools python3-wheel
#   python3-xdg python3.6-dev
# 0 upgraded, 73 newly installed, 0 to remove and 0 not upgraded.
# Need to get 77.0 MB of archives.
# After this operation, 210 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblocale-gettext-perl amd64 1.07-3build2 [16.6 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libelf1 amd64 0.170-0.4ubuntu0.1 [44.8 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libstdc++-7-dev amd64 7.5.0-3ubuntu1~18.04 [1471 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 g++-7 amd64 7.5.0-3ubuntu1~18.04 [9697 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 g++ amd64 4:7.4.0-1ubuntu2.3 [1568 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 make amd64 4.1-9.1ubuntu1 [154 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdpkg-perl all 1.19.0.5ubuntu2.3 [211 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 dpkg-dev all 1.19.0.5ubuntu2.3 [607 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 build-essential amd64 12.4ubuntu1 [4758 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-lib2to3 all 3.6.9-1~18.04 [77.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-distutils all 3.6.9-1~18.04 [144 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-python all 3.20180325ubuntu2 [89.2 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libassuan0 amd64 2.5.1-2 [35.0 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gpgconf amd64 2.2.4-1ubuntu1.4 [123 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libksba8 amd64 1.3.5-2 [92.6 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnpth0 amd64 1.5-3 [7668 B]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 dirmngr amd64 2.2.4-1ubuntu1.4 [316 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfakeroot amd64 1.22-2ubuntu1 [25.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 fakeroot amd64 1.22-2ubuntu1 [62.3 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libfreetype6 amd64 2.8.1-2ubuntu2.1 [335 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgraphite2-3 amd64 1.3.11-2 [78.7 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 libharfbuzz0b amd64 1.7.2-1ubuntu1 [232 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-harfbuzz-0.0 amd64 1.7.2-1ubuntu1 [18.6 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gnupg-l10n all 2.2.4-1ubuntu1.4 [49.8 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gnupg-utils amd64 2.2.4-1ubuntu1.4 [128 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gpg amd64 2.2.4-1ubuntu1.4 [467 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 pinentry-curses amd64 1.1.0-1 [35.8 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gpg-agent amd64 2.2.4-1ubuntu1.4 [227 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gpg-wks-client amd64 2.2.4-1ubuntu1.4 [91.8 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gpg-wks-server amd64 2.2.4-1ubuntu1.4 [85.0 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gpgsm amd64 2.2.4-1ubuntu1.4 [215 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gnupg amd64 2.2.4-1ubuntu1.4 [249 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 icu-devtools amd64 60.2-3ubuntu3.1 [179 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libalgorithm-diff-perl all 1.19.03-1 [47.6 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 libalgorithm-diff-xs-perl amd64 0.04-5 [11.1 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 libalgorithm-merge-perl all 0.08-3 [12.0 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libexpat1-dev amd64 2.2.5-3ubuntu0.2 [122 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfile-fcntllock-perl amd64 0.22-3build2 [33.2 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglib2.0-bin amd64 2.56.4-0ubuntu0.18.04.8 [68.5 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglib2.0-dev-bin amd64 2.56.4-0ubuntu0.18.04.8 [102 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpcre16-3 amd64 2:8.39-9 [147 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpcre32-3 amd64 2:8.39-9 [138 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpcrecpp0v5 amd64 2:8.39-9 [15.3 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpcre3-dev amd64 2:8.39-9 [537 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/main amd64 pkg-config amd64 0.29.1-0ubuntu2 [45.0 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglib2.0-dev amd64 2.56.4-0ubuntu0.18.04.8 [1386 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgraphite2-dev amd64 1.3.11-2 [14.5 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/main amd64 libharfbuzz-icu0 amd64 1.7.2-1ubuntu1 [5604 B]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/main amd64 libharfbuzz-gobject0 amd64 1.7.2-1ubuntu1 [13.4 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/main amd64 libicu-le-hb0 amd64 1.0.3+git161113-4 [14.3 kB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libiculx60 amd64 60.2-3ubuntu3.1 [19.0 kB]
# Get:52 http://archive.ubuntu.com/ubuntu bionic/main amd64 libicu-le-hb-dev amd64 1.0.3+git161113-4 [29.5 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libicu-dev amd64 60.2-3ubuntu3.1 [8889 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/main amd64 libharfbuzz-dev amd64 1.7.2-1ubuntu1 [302 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython3.6-dev amd64 3.6.9-1~18.04ubuntu1.4 [44.9 MB]
# Get:56 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython3-dev amd64 3.6.7-1~18.04 [7328 B]
# Get:57 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxml2-dev amd64 2.9.4+dfsg1-6.1ubuntu1.3 [756 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxslt1.1 amd64 1.1.29-5ubuntu0.2 [150 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxslt1-dev amd64 1.1.29-5ubuntu0.2 [407 kB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python-pip-whl all 9.0.1-2.3~ubuntu1.18.04.4 [1653 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-asn1crypto all 0.24.0-1 [72.8 kB]
# Get:62 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-cffi-backend amd64 1.11.5-1 [64.6 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-crypto amd64 2.6.1-8ubuntu2 [244 kB]
# Get:64 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-cryptography amd64 2.1.4-1ubuntu1.4 [220 kB]
# Get:65 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3.6-dev amd64 3.6.9-1~18.04ubuntu1.4 [508 kB]
# Get:66 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-dev amd64 3.6.7-1~18.04 [1288 B]
# Get:67 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-secretstorage all 2.3.1-2 [12.1 kB]
# Get:68 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-keyring all 10.6.0-1 [26.7 kB]
# Get:69 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-keyrings.alt all 3.0-1 [16.6 kB]
# Get:70 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python3-pip all 9.0.1-2.3~ubuntu1.18.04.4 [114 kB]
# Get:71 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-setuptools all 39.0.1-2 [248 kB]
# Get:72 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-wheel all 0.30.0-0.2 [36.5 kB]
# Get:73 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-xdg all 0.25-4ubuntu1.1 [31.3 kB]
# Fetched 77.0 MB in 11s (7251 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package liblocale-gettext-perl.
# (Reading database ... 18287 files and directories currently installed.)
# Preparing to unpack .../00-liblocale-gettext-perl_1.07-3build2_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking liblocale-gettext-perl (1.07-3build2) ...
# Selecting previously unselected package libelf1:amd64.
# Preparing to unpack .../01-libelf1_0.170-0.4ubuntu0.1_amd64.deb ...
# 7Progress: [  1%] [..........................................................] 8Unpacking libelf1:amd64 (0.170-0.4ubuntu0.1) ...
# Selecting previously unselected package libstdc++-7-dev:amd64.
# Preparing to unpack .../02-libstdc++-7-dev_7.5.0-3ubuntu1~18.04_amd64.deb ...
# Unpacking libstdc++-7-dev:amd64 (7.5.0-3ubuntu1~18.04) ...
# 7Progress: [  2%] [#.........................................................] 8Selecting previously unselected package g++-7.
# Preparing to unpack .../03-g++-7_7.5.0-3ubuntu1~18.04_amd64.deb ...
# Unpacking g++-7 (7.5.0-3ubuntu1~18.04) ...
# 7Progress: [  3%] [#.........................................................] 8Selecting previously unselected package g++.
# Preparing to unpack .../04-g++_4%3a7.4.0-1ubuntu2.3_amd64.deb ...
# Unpacking g++ (4:7.4.0-1ubuntu2.3) ...
# 7Progress: [  4%] [##........................................................] 8Selecting previously unselected package make.
# Preparing to unpack .../05-make_4.1-9.1ubuntu1_amd64.deb ...
# Unpacking make (4.1-9.1ubuntu1) ...
# Selecting previously unselected package libdpkg-perl.
# Preparing to unpack .../06-libdpkg-perl_1.19.0.5ubuntu2.3_all.deb ...
# 7Progress: [  5%] [###.......................................................] 8Unpacking libdpkg-perl (1.19.0.5ubuntu2.3) ...
# Selecting previously unselected package dpkg-dev.
# Preparing to unpack .../07-dpkg-dev_1.19.0.5ubuntu2.3_all.deb ...
# 7Progress: [  6%] [###.......................................................] 8Unpacking dpkg-dev (1.19.0.5ubuntu2.3) ...
# Selecting previously unselected package build-essential.
# Preparing to unpack .../08-build-essential_12.4ubuntu1_amd64.deb ...
# Unpacking build-essential (12.4ubuntu1) ...
# 7Progress: [  7%] [####......................................................] 8Selecting previously unselected package python3-lib2to3.
# Preparing to unpack .../09-python3-lib2to3_3.6.9-1~18.04_all.deb ...
# Unpacking python3-lib2to3 (3.6.9-1~18.04) ...
# 7Progress: [  8%] [####......................................................] 8Selecting previously unselected package python3-distutils.
# Preparing to unpack .../10-python3-distutils_3.6.9-1~18.04_all.deb ...
# Unpacking python3-distutils (3.6.9-1~18.04) ...
# 7Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package dh-python.
# Preparing to unpack .../11-dh-python_3.20180325ubuntu2_all.deb ...
# Unpacking dh-python (3.20180325ubuntu2) ...
# Selecting previously unselected package libassuan0:amd64.
# Preparing to unpack .../12-libassuan0_2.5.1-2_amd64.deb ...
# 7Progress: [ 10%] [#####.....................................................] 8Unpacking libassuan0:amd64 (2.5.1-2) ...
# Selecting previously unselected package gpgconf.
# Preparing to unpack .../13-gpgconf_2.2.4-1ubuntu1.4_amd64.deb ...
# Unpacking gpgconf (2.2.4-1ubuntu1.4) ...
# 7Progress: [ 11%] [######....................................................] 8Selecting previously unselected package libksba8:amd64.
# Preparing to unpack .../14-libksba8_1.3.5-2_amd64.deb ...
# Unpacking libksba8:amd64 (1.3.5-2) ...
# 7Progress: [ 12%] [######....................................................] 8Selecting previously unselected package libnpth0:amd64.
# Preparing to unpack .../15-libnpth0_1.5-3_amd64.deb ...
# Unpacking libnpth0:amd64 (1.5-3) ...
# 7Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package dirmngr.
# Preparing to unpack .../16-dirmngr_2.2.4-1ubuntu1.4_amd64.deb ...
# Unpacking dirmngr (2.2.4-1ubuntu1.4) ...
# Selecting previously unselected package libfakeroot:amd64.
# Preparing to unpack .../17-libfakeroot_1.22-2ubuntu1_amd64.deb ...
# 7Progress: [ 14%] [########..................................................] 8Unpacking libfakeroot:amd64 (1.22-2ubuntu1) ...
# Selecting previously unselected package fakeroot.
# Preparing to unpack .../18-fakeroot_1.22-2ubuntu1_amd64.deb ...
# 7Progress: [ 15%] [########..................................................] 8Unpacking fakeroot (1.22-2ubuntu1) ...
# Selecting previously unselected package libfreetype6:amd64.
# Preparing to unpack .../19-libfreetype6_2.8.1-2ubuntu2.1_amd64.deb ...
# Unpacking libfreetype6:amd64 (2.8.1-2ubuntu2.1) ...
# 7Progress: [ 16%] [#########.................................................] 8Selecting previously unselected package libgraphite2-3:amd64.
# Preparing to unpack .../20-libgraphite2-3_1.3.11-2_amd64.deb ...
# Unpacking libgraphite2-3:amd64 (1.3.11-2) ...
# 7Progress: [ 17%] [#########.................................................] 8Selecting previously unselected package libharfbuzz0b:amd64.
# Preparing to unpack .../21-libharfbuzz0b_1.7.2-1ubuntu1_amd64.deb ...
# Unpacking libharfbuzz0b:amd64 (1.7.2-1ubuntu1) ...
# 7Progress: [ 18%] [##########................................................] 8Selecting previously unselected package gir1.2-harfbuzz-0.0:amd64.
# Preparing to unpack .../22-gir1.2-harfbuzz-0.0_1.7.2-1ubuntu1_amd64.deb ...
# Unpacking gir1.2-harfbuzz-0.0:amd64 (1.7.2-1ubuntu1) ...
# Selecting previously unselected package gnupg-l10n.
# Preparing to unpack .../23-gnupg-l10n_2.2.4-1ubuntu1.4_all.deb ...
# 7Progress: [ 19%] [###########...............................................] 8Unpacking gnupg-l10n (2.2.4-1ubuntu1.4) ...
# Selecting previously unselected package gnupg-utils.
# Preparing to unpack .../24-gnupg-utils_2.2.4-1ubuntu1.4_amd64.deb ...
# Unpacking gnupg-utils (2.2.4-1ubuntu1.4) ...
# 7Progress: [ 20%] [###########...............................................] 8Selecting previously unselected package gpg.
# Preparing to unpack .../25-gpg_2.2.4-1ubuntu1.4_amd64.deb ...
# Unpacking gpg (2.2.4-1ubuntu1.4) ...
# 7Progress: [ 21%] [############..............................................] 8Selecting previously unselected package pinentry-curses.
# Preparing to unpack .../26-pinentry-curses_1.1.0-1_amd64.deb ...
# Unpacking pinentry-curses (1.1.0-1) ...
# 7Progress: [ 22%] [############..............................................] 8Selecting previously unselected package gpg-agent.
# Preparing to unpack .../27-gpg-agent_2.2.4-1ubuntu1.4_amd64.deb ...
# Unpacking gpg-agent (2.2.4-1ubuntu1.4) ...
# Selecting previously unselected package gpg-wks-client.
# Preparing to unpack .../28-gpg-wks-client_2.2.4-1ubuntu1.4_amd64.deb ...
# 7Progress: [ 23%] [#############.............................................] 8Unpacking gpg-wks-client (2.2.4-1ubuntu1.4) ...
# Selecting previously unselected package gpg-wks-server.
# Preparing to unpack .../29-gpg-wks-server_2.2.4-1ubuntu1.4_amd64.deb ...
# 7Progress: [ 24%] [#############.............................................] 8Unpacking gpg-wks-server (2.2.4-1ubuntu1.4) ...
# Selecting previously unselected package gpgsm.
# Preparing to unpack .../30-gpgsm_2.2.4-1ubuntu1.4_amd64.deb ...
# Unpacking gpgsm (2.2.4-1ubuntu1.4) ...
# 7Progress: [ 25%] [##############............................................] 8Selecting previously unselected package gnupg.
# Preparing to unpack .../31-gnupg_2.2.4-1ubuntu1.4_amd64.deb ...
# Unpacking gnupg (2.2.4-1ubuntu1.4) ...
# 7Progress: [ 26%] [###############...........................................] 8Selecting previously unselected package icu-devtools.
# Preparing to unpack .../32-icu-devtools_60.2-3ubuntu3.1_amd64.deb ...
# Unpacking icu-devtools (60.2-3ubuntu3.1) ...
# 7Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package libalgorithm-diff-perl.
# Preparing to unpack .../33-libalgorithm-diff-perl_1.19.03-1_all.deb ...
# Unpacking libalgorithm-diff-perl (1.19.03-1) ...
# Selecting previously unselected package libalgorithm-diff-xs-perl.
# Preparing to unpack .../34-libalgorithm-diff-xs-perl_0.04-5_amd64.deb ...
# 7Progress: [ 28%] [################..........................................] 8Unpacking libalgorithm-diff-xs-perl (0.04-5) ...
# Selecting previously unselected package libalgorithm-merge-perl.
# Preparing to unpack .../35-libalgorithm-merge-perl_0.08-3_all.deb ...
# Unpacking libalgorithm-merge-perl (0.08-3) ...
# 7Progress: [ 29%] [################..........................................] 8Selecting previously unselected package libexpat1-dev:amd64.
# Preparing to unpack .../36-libexpat1-dev_2.2.5-3ubuntu0.2_amd64.deb ...
# Unpacking libexpat1-dev:amd64 (2.2.5-3ubuntu0.2) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libfile-fcntllock-perl.
# Preparing to unpack .../37-libfile-fcntllock-perl_0.22-3build2_amd64.deb ...
# Unpacking libfile-fcntllock-perl (0.22-3build2) ...
# 7Progress: [ 31%] [##################........................................] 8Selecting previously unselected package libglib2.0-bin.
# Preparing to unpack .../38-libglib2.0-bin_2.56.4-0ubuntu0.18.04.8_amd64.deb ...
# Unpacking libglib2.0-bin (2.56.4-0ubuntu0.18.04.8) ...
# Selecting previously unselected package libglib2.0-dev-bin.
# Preparing to unpack .../39-libglib2.0-dev-bin_2.56.4-0ubuntu0.18.04.8_amd64.deb ...
# 7Progress: [ 32%] [##################........................................] 8Unpacking libglib2.0-dev-bin (2.56.4-0ubuntu0.18.04.8) ...
# Selecting previously unselected package libpcre16-3:amd64.
# Preparing to unpack .../40-libpcre16-3_2%3a8.39-9_amd64.deb ...
# 7Progress: [ 33%] [###################.......................................] 8Unpacking libpcre16-3:amd64 (2:8.39-9) ...
# Selecting previously unselected package libpcre32-3:amd64.
# Preparing to unpack .../41-libpcre32-3_2%3a8.39-9_amd64.deb ...
# Unpacking libpcre32-3:amd64 (2:8.39-9) ...
# 7Progress: [ 34%] [###################.......................................] 8Selecting previously unselected package libpcrecpp0v5:amd64.
# Preparing to unpack .../42-libpcrecpp0v5_2%3a8.39-9_amd64.deb ...
# Unpacking libpcrecpp0v5:amd64 (2:8.39-9) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package libpcre3-dev:amd64.
# Preparing to unpack .../43-libpcre3-dev_2%3a8.39-9_amd64.deb ...
# Unpacking libpcre3-dev:amd64 (2:8.39-9) ...
# 7Progress: [ 36%] [####################......................................] 8Selecting previously unselected package pkg-config.
# Preparing to unpack .../44-pkg-config_0.29.1-0ubuntu2_amd64.deb ...
# Unpacking pkg-config (0.29.1-0ubuntu2) ...
# Selecting previously unselected package libglib2.0-dev:amd64.
# Preparing to unpack .../45-libglib2.0-dev_2.56.4-0ubuntu0.18.04.8_amd64.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libglib2.0-dev:amd64 (2.56.4-0ubuntu0.18.04.8) ...
# Selecting previously unselected package libgraphite2-dev:amd64.
# Preparing to unpack .../46-libgraphite2-dev_1.3.11-2_amd64.deb ...
# Unpacking libgraphite2-dev:amd64 (1.3.11-2) ...
# 7Progress: [ 38%] [######################....................................] 8Selecting previously unselected package libharfbuzz-icu0:amd64.
# Preparing to unpack .../47-libharfbuzz-icu0_1.7.2-1ubuntu1_amd64.deb ...
# Unpacking libharfbuzz-icu0:amd64 (1.7.2-1ubuntu1) ...
# 7Progress: [ 39%] [######################....................................] 8Selecting previously unselected package libharfbuzz-gobject0:amd64.
# Preparing to unpack .../48-libharfbuzz-gobject0_1.7.2-1ubuntu1_amd64.deb ...
# Unpacking libharfbuzz-gobject0:amd64 (1.7.2-1ubuntu1) ...
# Selecting previously unselected package libicu-le-hb0:amd64.
# Preparing to unpack .../49-libicu-le-hb0_1.0.3+git161113-4_amd64.deb ...
# 7Progress: [ 40%] [#######################...................................] 8Unpacking libicu-le-hb0:amd64 (1.0.3+git161113-4) ...
# Selecting previously unselected package libiculx60:amd64.
# Preparing to unpack .../50-libiculx60_60.2-3ubuntu3.1_amd64.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking libiculx60:amd64 (60.2-3ubuntu3.1) ...
# Selecting previously unselected package libicu-le-hb-dev:amd64.
# Preparing to unpack .../51-libicu-le-hb-dev_1.0.3+git161113-4_amd64.deb ...
# Unpacking libicu-le-hb-dev:amd64 (1.0.3+git161113-4) ...
# 7Progress: [ 42%] [########################..................................] 8Selecting previously unselected package libicu-dev.
# Preparing to unpack .../52-libicu-dev_60.2-3ubuntu3.1_amd64.deb ...
# Unpacking libicu-dev (60.2-3ubuntu3.1) ...
# 7Progress: [ 43%] [#########################.................................] 8Selecting previously unselected package libharfbuzz-dev:amd64.
# Preparing to unpack .../53-libharfbuzz-dev_1.7.2-1ubuntu1_amd64.deb ...
# Unpacking libharfbuzz-dev:amd64 (1.7.2-1ubuntu1) ...
# 7Progress: [ 44%] [#########################.................................] 8Selecting previously unselected package libpython3.6-dev:amd64.
# Preparing to unpack .../54-libpython3.6-dev_3.6.9-1~18.04ubuntu1.4_amd64.deb ...
# Unpacking libpython3.6-dev:amd64 (3.6.9-1~18.04ubuntu1.4) ...
# Selecting previously unselected package libpython3-dev:amd64.
# Preparing to unpack .../55-libpython3-dev_3.6.7-1~18.04_amd64.deb ...
# 7Progress: [ 45%] [##########################................................] 8Unpacking libpython3-dev:amd64 (3.6.7-1~18.04) ...
# Selecting previously unselected package libxml2-dev:amd64.
# Preparing to unpack .../56-libxml2-dev_2.9.4+dfsg1-6.1ubuntu1.3_amd64.deb ...
# Unpacking libxml2-dev:amd64 (2.9.4+dfsg1-6.1ubuntu1.3) ...
# 7Progress: [ 46%] [##########################................................] 8Selecting previously unselected package libxslt1.1:amd64.
# Preparing to unpack .../57-libxslt1.1_1.1.29-5ubuntu0.2_amd64.deb ...
# Unpacking libxslt1.1:amd64 (1.1.29-5ubuntu0.2) ...
# 7Progress: [ 47%] [###########################...............................] 8Selecting previously unselected package libxslt1-dev:amd64.
# Preparing to unpack .../58-libxslt1-dev_1.1.29-5ubuntu0.2_amd64.deb ...
# Unpacking libxslt1-dev:amd64 (1.1.29-5ubuntu0.2) ...
# 7Progress: [ 48%] [###########################...............................] 8Selecting previously unselected package python-pip-whl.
# Preparing to unpack .../59-python-pip-whl_9.0.1-2.3~ubuntu1.18.04.4_all.deb ...
# Unpacking python-pip-whl (9.0.1-2.3~ubuntu1.18.04.4) ...
# Selecting previously unselected package python3-asn1crypto.
# Preparing to unpack .../60-python3-asn1crypto_0.24.0-1_all.deb ...
# 7Progress: [ 49%] [############################..............................] 8Unpacking python3-asn1crypto (0.24.0-1) ...
# Selecting previously unselected package python3-cffi-backend.
# Preparing to unpack .../61-python3-cffi-backend_1.11.5-1_amd64.deb ...
# 7Progress: [ 50%] [#############################.............................] 8Unpacking python3-cffi-backend (1.11.5-1) ...
# Selecting previously unselected package python3-crypto.
# Preparing to unpack .../62-python3-crypto_2.6.1-8ubuntu2_amd64.deb ...
# Unpacking python3-crypto (2.6.1-8ubuntu2) ...
# 7Progress: [ 51%] [#############################.............................] 8Selecting previously unselected package python3-cryptography.
# Preparing to unpack .../63-python3-cryptography_2.1.4-1ubuntu1.4_amd64.deb ...
# Unpacking python3-cryptography (2.1.4-1ubuntu1.4) ...
# 7Progress: [ 52%] [##############################............................] 8Selecting previously unselected package python3.6-dev.
# Preparing to unpack .../64-python3.6-dev_3.6.9-1~18.04ubuntu1.4_amd64.deb ...
# Unpacking python3.6-dev (3.6.9-1~18.04ubuntu1.4) ...
# Selecting previously unselected package python3-dev.
# Preparing to unpack .../65-python3-dev_3.6.7-1~18.04_amd64.deb ...
# 7Progress: [ 53%] [##############################............................] 8Unpacking python3-dev (3.6.7-1~18.04) ...
# Selecting previously unselected package python3-secretstorage.
# Preparing to unpack .../66-python3-secretstorage_2.3.1-2_all.deb ...
# 7Progress: [ 54%] [###############################...........................] 8Unpacking python3-secretstorage (2.3.1-2) ...
# Selecting previously unselected package python3-keyring.
# Preparing to unpack .../67-python3-keyring_10.6.0-1_all.deb ...
# Unpacking python3-keyring (10.6.0-1) ...
# 7Progress: [ 55%] [###############################...........................] 8Selecting previously unselected package python3-keyrings.alt.
# Preparing to unpack .../68-python3-keyrings.alt_3.0-1_all.deb ...
# Unpacking python3-keyrings.alt (3.0-1) ...
# 7Progress: [ 56%] [################################..........................] 8Selecting previously unselected package python3-pip.
# Preparing to unpack .../69-python3-pip_9.0.1-2.3~ubuntu1.18.04.4_all.deb ...
# Unpacking python3-pip (9.0.1-2.3~ubuntu1.18.04.4) ...
# 7Progress: [ 57%] [#################################.........................] 8Selecting previously unselected package python3-setuptools.
# Preparing to unpack .../70-python3-setuptools_39.0.1-2_all.deb ...
# Unpacking python3-setuptools (39.0.1-2) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../71-python3-wheel_0.30.0-0.2_all.deb ...
# 7Progress: [ 58%] [#################################.........................] 8Unpacking python3-wheel (0.30.0-0.2) ...
# Selecting previously unselected package python3-xdg.
# Preparing to unpack .../72-python3-xdg_0.25-4ubuntu1.1_all.deb ...
# Unpacking python3-xdg (0.25-4ubuntu1.1) ...
# 7Progress: [ 59%] [##################################........................] 8Setting up libnpth0:amd64 (1.5-3) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up python-pip-whl (9.0.1-2.3~ubuntu1.18.04.4) ...
# Setting up make (4.1-9.1ubuntu1) ...
# 7Progress: [ 61%] [###################################.......................] 8Setting up python3-cffi-backend (1.11.5-1) ...
# Setting up python3-crypto (2.6.1-8ubuntu2) ...
# 7Progress: [ 62%] [####################################......................] 8Setting up libelf1:amd64 (0.170-0.4ubuntu0.1) ...
# Setting up python3-xdg (0.25-4ubuntu1.1) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up python3-keyrings.alt (3.0-1) ...
# Setting up libdpkg-perl (1.19.0.5ubuntu2.3) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libksba8:amd64 (1.3.5-2) ...
# Setting up python3-wheel (0.30.0-0.2) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up libfreetype6:amd64 (2.8.1-2ubuntu2.1) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up gnupg-l10n (2.2.4-1ubuntu1.4) ...
# Setting up libgraphite2-3:amd64 (1.3.11-2) ...
# 7Progress: [ 67%] [######################################....................] 8Setting up libxslt1.1:amd64 (1.1.29-5ubuntu0.2) ...
# Setting up libstdc++-7-dev:amd64 (7.5.0-3ubuntu1~18.04) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up python3-asn1crypto (0.24.0-1) ...
# Setting up libfile-fcntllock-perl (0.22-3build2) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up dpkg-dev (1.19.0.5ubuntu2.3) ...
# Setting up libfakeroot:amd64 (1.22-2ubuntu1) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up libalgorithm-diff-perl (1.19.03-1) ...
# Setting up liblocale-gettext-perl (1.07-3build2) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libexpat1-dev:amd64 (2.2.5-3ubuntu0.2) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up libpcrecpp0v5:amd64 (2:8.39-9) ...
# Setting up libpcre32-3:amd64 (2:8.39-9) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up icu-devtools (60.2-3ubuntu3.1) ...
# Setting up libpcre16-3:amd64 (2:8.39-9) ...
# 7Progress: [ 74%] [###########################################...............] 8Setting up python3-lib2to3 (3.6.9-1~18.04) ...
# Setting up libglib2.0-bin (2.56.4-0ubuntu0.18.04.8) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libgraphite2-dev:amd64 (1.3.11-2) ...
# Setting up libassuan0:amd64 (2.5.1-2) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up python3-distutils (3.6.9-1~18.04) ...
# Setting up python3-cryptography (2.1.4-1ubuntu1.4) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libpcre3-dev:amd64 (2:8.39-9) ...
# Setting up libglib2.0-dev-bin (2.56.4-0ubuntu0.18.04.8) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up g++-7 (7.5.0-3ubuntu1~18.04) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up gpgconf (2.2.4-1ubuntu1.4) ...
# Setting up libharfbuzz0b:amd64 (1.7.2-1ubuntu1) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up fakeroot (1.22-2ubuntu1) ...
# update-alternatives: using /usr/bin/fakeroot-sysv to provide /usr/bin/fakeroot (fakeroot) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/fakeroot.1.gz because associated file /usr/share/man/man1/fakeroot-sysv.1.gz (of link group fakeroot) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/faked.1.gz because associated file /usr/share/man/man1/faked-sysv.1.gz (of link group fakeroot) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/es/man1/fakeroot.1.gz because associated file /usr/share/man/es/man1/fakeroot-sysv.1.gz (of link group fakeroot) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/es/man1/faked.1.gz because associated file /usr/share/man/es/man1/faked-sysv.1.gz (of link group fakeroot) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/fr/man1/fakeroot.1.gz because associated file /usr/share/man/fr/man1/fakeroot-sysv.1.gz (of link group fakeroot) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/fr/man1/faked.1.gz because associated file /usr/share/man/fr/man1/faked-sysv.1.gz (of link group fakeroot) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/sv/man1/fakeroot.1.gz because associated file /usr/share/man/sv/man1/fakeroot-sysv.1.gz (of link group fakeroot) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/sv/man1/faked.1.gz because associated file /usr/share/man/sv/man1/faked-sysv.1.gz (of link group fakeroot) doesn't exist
# Setting up libpython3.6-dev:amd64 (3.6.9-1~18.04ubuntu1.4) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up libalgorithm-merge-perl (0.08-3) ...
# Setting up pkg-config (0.29.1-0ubuntu2) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libalgorithm-diff-xs-perl (0.04-5) ...
# Setting up gir1.2-harfbuzz-0.0:amd64 (1.7.2-1ubuntu1) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up gpgsm (2.2.4-1ubuntu1.4) ...
# Setting up python3-pip (9.0.1-2.3~ubuntu1.18.04.4) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up gnupg-utils (2.2.4-1ubuntu1.4) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up g++ (4:7.4.0-1ubuntu2.3) ...
# update-alternatives: using /usr/bin/g++ to provide /usr/bin/c++ (c++) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/c++.1.gz because associated file /usr/share/man/man1/g++.1.gz (of link group c++) doesn't exist
# Setting up pinentry-curses (1.1.0-1) ...
# 7Progress: [ 86%] [#################################################.........] 8Setting up python3-setuptools (39.0.1-2) ...
# Setting up python3.6-dev (3.6.9-1~18.04ubuntu1.4) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up python3-secretstorage (2.3.1-2) ...
# Setting up dirmngr (2.2.4-1ubuntu1.4) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up dh-python (3.20180325ubuntu2) ...
# Setting up libharfbuzz-gobject0:amd64 (1.7.2-1ubuntu1) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up gpg (2.2.4-1ubuntu1.4) ...
# Setting up libpython3-dev:amd64 (3.6.7-1~18.04) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libharfbuzz-icu0:amd64 (1.7.2-1ubuntu1) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up python3-keyring (10.6.0-1) ...
# Setting up build-essential (12.4ubuntu1) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libicu-le-hb0:amd64 (1.0.3+git161113-4) ...
# Setting up gpg-agent (2.2.4-1ubuntu1.4) ...
# 7Progress: [ 93%] [######################################################....] 8Setting up python3-dev (3.6.7-1~18.04) ...
# Setting up gpg-wks-server (2.2.4-1ubuntu1.4) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up gpg-wks-client (2.2.4-1ubuntu1.4) ...
# Setting up libglib2.0-dev:amd64 (2.56.4-0ubuntu0.18.04.8) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up libiculx60:amd64 (60.2-3ubuntu3.1) ...
# Setting up gnupg (2.2.4-1ubuntu1.4) ...
# 7Progress: [ 96%] [#######################################################...] 8Processing triggers for libc-bin (2.27-3ubuntu1.4) ...
# Processing triggers for libglib2.0-0:amd64 (2.56.4-0ubuntu0.18.04.8) ...
# No schema files found: doing nothing.
# 7Progress: [ 97%] [########################################################..] 8Setting up libharfbuzz-dev:amd64 (1.7.2-1ubuntu1) ...
# Setting up libicu-le-hb-dev:amd64 (1.0.3+git161113-4) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up libicu-dev (60.2-3ubuntu3.1) ...
# Setting up libxml2-dev:amd64 (2.9.4+dfsg1-6.1ubuntu1.3) ...
# 7Progress: [ 99%] [#########################################################.] 8Setting up libxslt1-dev:amd64 (1.1.29-5ubuntu0.2) ...
#
# 78

# %%
# !pip install git+https://github.com/lucasb-eyer/pydensecrf.git
# Out:
# Collecting git+https://github.com/lucasb-eyer/pydensecrf.git
#   Cloning https://github.com/lucasb-eyer/pydensecrf.git to /tmp/pip-req-build-dedkxbaq
#   Running command git clone -q https://github.com/lucasb-eyer/pydensecrf.git /tmp/pip-req-build-dedkxbaq
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Building wheels for collected packages: pydensecrf
#   Building wheel for pydensecrf (PEP 517) ... done
#   Created wheel for pydensecrf: filename=pydensecrf-1.0rc2-cp37-cp37m-linux_x86_64.whl size=2898466 sha256=d25717ea6357fbe1ab06e13cd4e00c7de33950a6222dcbd15515ea9e56ba6188
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fjld41th/wheels/c1/7e/80/99adc0b2f215180486e24dd9c700028343ba5f566514a0ef05
# Successfully built pydensecrf
# Installing collected packages: pydensecrf
# Successfully installed pydensecrf-1.0rc2

# %%
import os
import random
import time
import json
import warnings 
warnings.filterwarnings('ignore')

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
from utils import *
import cv2
from sklearn.model_selection import StratifiedKFold
import zipfile

import numpy as np
import pandas as pd
from tqdm.auto import tqdm

# Pretrained Model
import segmentation_models_pytorch as smp

# CRF
import pydensecrf.densecrf as dcrf
import pydensecrf.utils as utils

# torchvision Models
import torchvision
from torchvision import models
from torchvision.models.segmentation.deeplabv3 import DeepLabHead

# 전처리를 위한 라이브러리
from torch.utils.data.sampler import WeightedRandomSampler
from pycocotools.coco import COCO
import torchvision
import torchvision.transforms as transforms

import albumentations as A
from albumentations.pytorch import ToTensorV2

# 시각화를 위한 라이브러리
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

plt.rcParams['axes.grid'] = False

print('pytorch version: {}'.format(torch.__version__))
print('GPU 사용 가능 여부: {}'.format(torch.cuda.is_available()))

print(torch.cuda.get_device_name(0))
print(torch.cuda.device_count())

device = "cuda" if torch.cuda.is_available() else "cpu"   # GPU 사용 가능 여부에 따라 device 정보 저장
# %matplotlib inline
# Out:
# pytorch version: 1.5.1+cu101
# GPU 사용 가능 여부: True
# Tesla V100-PCIE-32GB
# 1

# %% [markdown]
# ## 하이퍼파라미터 세팅 및 seed 고정

# %%
batch_size = 20  # Mini-batch size
num_epochs = 40
learning_rate = 1e-4

# %%
# seed 고정
random_seed = 42
torch.manual_seed(random_seed)
torch.cuda.manual_seed(random_seed)
# torch.cuda.manual_seed_all(random_seed) # if use multi-GPU
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(random_seed)
random.seed(random_seed)

# %%
class CustomDataLoader(Dataset):
    """COCO format"""
    def __init__(self, data_dir, mode = 'test', transform = None):
        super().__init__()
        self.mode = mode
        self.transform = transform
        self.coco = COCO(data_dir)
        
    def __getitem__(self, index: int):
        # dataset이 index되어 list처럼 동작
        image_id = self.coco.getImgIds(imgIds=index)
        image_infos = self.coco.loadImgs(image_id)[0]
        
        # cv2 를 활용하여 image 불러오기
        images = cv2.imread(os.path.join('../input/data', image_infos['file_name']))
        images = cv2.cvtColor(images, cv2.COLOR_BGR2RGB)
        
        if self.mode == 'test':
            # transform -> albumentations 라이브러리 활용
            if self.transform is not None:
                transformed = self.transform(image=images)
                images = transformed["image"]
            
            return images, image_infos
    
    
    def __len__(self) -> int:
        # 전체 dataset의 size를 return
        return len(self.coco.getImgIds())

# %% [markdown]
# ## Dataset 정의 및 DataLoader 할당

# %%
# collate_fn needs for batch
def collate_fn(batch):
    return tuple(zip(*batch))

test_transform = A.Compose([
                            A.Normalize(
                                mean=(0.485, 0.456, 0.406),
                                std=(0.229, 0.224, 0.225), max_pixel_value=255.0, p=1.0
                            ),
                            ToTensorV2(),
                           ])

# %%
test_dataset = CustomDataLoader('../input/data/test.json', mode="test", transform=test_transform)

test_loader = DataLoader(test_dataset, 
                          batch_size=1, 
                          num_workers=4,
                         shuffle=False,
                         collate_fn=collate_fn)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!

# %% [markdown]
# ## Inference Load Model

# %%
MODEL_PATHS = ['../single_best_weight/0_checkpoint.pt',
                '../single_best_weight/1_checkpoint.pt',
                '../single_best_weight/2_checkpoint.pt',
                '../single_best_weight/3_checkpoint.pt',
                '../single_best_weight/4_checkpoint.pt']

OUT_MASKS = f'./saved/test_masks.zip'

SOFTMAX = nn.Softmax(dim=1)

# %%
MAX_ITER = 5
POS_W = 3
POS_XY_STD = 1
Bi_W = 4
Bi_XY_STD = 67
Bi_RGB_STD = 3

def dense_crf(img, prob):
    """https://github.com/zllrunning/deeplab-pytorch-crf"""
    c, h, w = prob.shape
    U = utils.unary_from_softmax(prob)
    U = np.ascontiguousarray(U)
    img = np.ascontiguousarray(img)
    d = dcrf.DenseCRF2D(w, h, c)
    d.setUnaryEnergy(U)
    d.addPairwiseGaussian(sxy=POS_XY_STD, compat=POS_W)
    d.addPairwiseBilateral(sxy=Bi_XY_STD, srgb=Bi_RGB_STD, rgbim=img, compat=Bi_W)
    Q = d.inference(MAX_ITER)
    return np.array(Q).reshape((c, h, w))

# %%
def inference(models, imgs, device):
    outs = None
    flip_outs = None
    flips = [[-1],[-2],[-2,-1]]
    for model in models:
        model.eval()
        if outs == None:
            outs = model(imgs.to(device).float()).detach()
        else:
            outs += model(imgs.to(device).float()).detach()
             
    for flip in flips:
        flip_img = torch.flip(imgs, flip)
        tmp_outs = None
        for model in models:
            flip_out = model(flip_img.to(device).float()).detach()
            flip_out = torch.flip(flip_out, flip)
            if tmp_outs == None:
                tmp_outs = flip_out
            else:
                tmp_outs += flip_out
        if flip_outs == None:
            flip_outs = tmp_outs
        else:
            flip_outs += tmp_outs
    
    outs += flip_outs
    
    return outs/(len(models)+len(flips)+len(models))

# %% [markdown]
# ## Inference

# %%
def test(models, data_loader, device):
    size = 256
    transform = A.Compose([A.Resize(256, 256)])
    print('Start prediction.')
    file_name_list = []
    preds_array = np.empty((0, size*size), dtype=np.long)
    pbar = tqdm(enumerate(data_loader), total=len(data_loader), position=0, leave=True)
    with torch.no_grad():
        with zipfile.ZipFile(OUT_MASKS, 'w') as mask_out:
            for step, (imgs, image_infos) in pbar:
                # print(imgs)
                # print(imgs)
                imgs = torch.stack(imgs)

                outs = SOFTMAX(inference(models, imgs, device))

                image = imgs.squeeze().data.cpu().numpy().astype(np.uint8).transpose(1,2,0)
                prob = outs.squeeze().data.cpu().numpy()

                prob = dense_crf(image,prob)
                
                outs = torch.Tensor(prob).unsqueeze(0)

                oms = torch.argmax(outs, dim=1).detach().cpu().numpy()
                
                file_name = image_infos[0]['file_name'].split("/")
                file_name[0] += "_masks"
                file_name[1] = file_name[1][:-4]
                file_name = "/".join(file_name)

                m = cv2.imencode(".png", oms.squeeze())[1]
                mask_out.writestr(f"{file_name}.png", m)

                # resize (256 x 256)
                temp_mask = []
                for img, mask in zip(np.stack(imgs), oms):
                    # print(mask.shape)
                    transformed = transform(image=img, mask=mask)
                    mask = transformed['mask']
                    temp_mask.append(mask)

                oms = np.array(temp_mask)
                oms = oms.reshape([oms.shape[0], size*size]).astype(int)

                preds_array = np.vstack((preds_array, oms))

                file_name_list.append([i['file_name'] for i in image_infos])
    print("End prediction.")
    file_names = [y for x in file_name_list for y in x]
    
    return file_names, preds_array

# %%
models=[]
for path in MODEL_PATHS:
    model = smp.DeepLabV3Plus('resnext50_32x4d', encoder_weights=None, classes=12)
    checkpoint = torch.load(path)
    model.load_state_dict(checkpoint)
    model.eval()
    model.to(device)
    models.append(model)
    
    del checkpoint

# %%
file_names, preds = test(models, test_loader, device)
# Out:
# Start prediction.
#   0%|          | 0/837 [00:00<?, ?it/s]
# End prediction.

# %% [markdown]
# ## submission.csv 생성

# %%
# sample_submisson.csv 열기
submission = pd.read_csv('./submission/sample_submission.csv', index_col=None)

# PredictionString 대입
for file_name, string in zip(file_names, preds):
    submission = submission.append({"image_id" : file_name, "PredictionString" : ' '.join(str(e) for e in string.tolist())}, 
                                   ignore_index=True)

# submission.csv로 저장
submission.to_csv("./submission/psheudo_3_CRF.csv", index=False)

# %% [markdown]
# ## Reference
